# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\noemi\Documents\GitHub\Data-mining-project\datasets\Final_version\final_numarical_dataset.csv')
df.head()
# Out:
#            region  danceability  energy  key  loudness  mode  speechiness  \
# 0   Latin America         0.685   0.644   10   -13.206     0       0.1550
# 1   Latin America         0.748   0.627    7    -6.029     1       0.0639
# 2   Latin America         0.509   0.803    0    -6.743     1       0.0400
# 3  Eastern Europe         0.703   0.226    7   -13.457     1       0.0403
# 4  Eastern Europe         0.472   0.349    1    -7.340     1       0.0346
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.302          0.000055    0.1140    0.808  164.919       169379
# 1         0.131          0.000000    0.0852    0.524  120.963       188491
# 2         0.684          0.000539    0.4630    0.651  166.018       187119
# 3         0.889          0.028400    0.0652    0.117  118.945       226387
# 4         0.143          0.000063    0.0930    0.136  121.054       187000
#
#    time_signature  popular
# 0               4        0
# ...

# %%
print(df['region'].head())
# Out:
# 0     Latin America
# 1     Latin America
# 2     Latin America
# 3    Eastern Europe
# 4    Eastern Europe
# Name: region, dtype: object

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
#encoding

from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
df['region']=le.fit_transform(df['region'])
label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(label_mapping)
# Out:
# {'Africa': 0, 'East Asia': 1, 'Eastern Europe': 2, 'Latin America': 3, 'Middle East': 4, 'North America': 5, 'Northern Europe': 6, 'Oceania': 7, 'South Asia': 8, 'Southern Europe': 9, 'Western Europe': 10}

# %%
df.head()
# Out:
#    region  danceability  energy  key  loudness  mode  speechiness  \
# 0       3         0.685   0.644   10   -13.206     0       0.1550
# 1       3         0.748   0.627    7    -6.029     1       0.0639
# 2       3         0.509   0.803    0    -6.743     1       0.0400
# 3       2         0.703   0.226    7   -13.457     1       0.0403
# 4       2         0.472   0.349    1    -7.340     1       0.0346
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.302          0.000055    0.1140    0.808  164.919       169379
# 1         0.131          0.000000    0.0852    0.524  120.963       188491
# 2         0.684          0.000539    0.4630    0.651  166.018       187119
# 3         0.889          0.028400    0.0652    0.117  118.945       226387
# 4         0.143          0.000063    0.0930    0.136  121.054       187000
#
#    time_signature  popular
# 0               4        0
# 1               4        0
# 2               4        0
# ...

# %%
unique_values = df['region'].unique()
print(unique_values)
# Out:
# [ 3  2 10  1  8  0  6  9  5  7  4]

# %%
print(df['region'].head())
# Out:
# 0    3
# 1    3
# 2    3
# 3    2
# 4    2
# Name: region, dtype: int32

# %%
df.to_csv(r'C:\Users\noemi\Documents\GitHub\Data-mining-project\datasets\Final_version\final_dataset.csv', index=False)
